# %% [markdown]
# <a href="https://colab.research.google.com/github/Tankasala25/NVIDIA-Triton-Inference-Server/blob/main/Updatingrowsandcolumns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
People={
    'first':['Rao','ajay','vijay'],
    'last':['Tankasala','Johnson','Johnson'],
    'email':['raotankasala@gmail.com','ajayjohnson@gmail.com','vijaydart@gmail.com']
}

# %%
df=pd.DataFrame(People)

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  raotankasala@gmail.com
# 1   ajay    Johnson   ajayjohnson@gmail.com
# 2  vijay    Johnson     vijaydart@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
##updating Columns
df.columns=['first_name','last_name','email']

# %%
df
# Out:
#   first_name  last_name                   email
# 0        Rao  Tankasala  raotankasala@gmail.com
# 1       ajay    Johnson   ajayjohnson@gmail.com
# 2      vijay    Johnson     vijaydart@gmail.com

# %%
#list comprehensions to do it upper case of column names
df.columns=[x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME  LAST_NAME                   EMAIL
# 0        Rao  Tankasala  raotankasala@gmail.com
# 1       ajay    Johnson   ajayjohnson@gmail.com
# 2      vijay    Johnson     vijaydart@gmail.com

# %%
#replace underscore with space
df.columns=df.columns.str.replace('_',' ')

# %%
df
# Out:
#   FIRST NAME  LAST NAME                   EMAIL
# 0        Rao  Tankasala  raotankasala@gmail.com
# 1       ajay    Johnson   ajayjohnson@gmail.com
# 2      vijay    Johnson     vijaydart@gmail.com

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df
# Out:
#   FIRST_NAME  LAST_NAME                   EMAIL
# 0        Rao  Tankasala  raotankasala@gmail.com
# 1       ajay    Johnson   ajayjohnson@gmail.com
# 2      vijay    Johnson     vijaydart@gmail.com

# %%
# lowwer the column names
df.columns=[x.lower() for x in df.columns]

# %%
df
# Out:
#   first_name  last_name                   email
# 0        Rao  Tankasala  raotankasala@gmail.com
# 1       ajay    Johnson   ajayjohnson@gmail.com
# 2      vijay    Johnson     vijaydart@gmail.com

# %%
# if you want to change column namess
df.rename(columns={'first_name':'first','last_name':'last', 'email':'email'},inplace=True)

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  raotankasala@gmail.com
# 1   ajay    Johnson   ajayjohnson@gmail.com
# 2  vijay    Johnson     vijaydart@gmail.com

# %%
#let's change vijay johnson lastname to danson, we set all values to change
df.loc[2]=['Vijay','Danson','vijaydanson@gmail.com']

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  raotankasala@gmail.com
# 1   ajay    Johnson   ajayjohnson@gmail.com
# 2  Vijay     Danson   vijaydanson@gmail.com

# %%
# we particular thing to update
df.loc[2,'last']='Johnson'

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  raotankasala@gmail.com
# 1   ajay    Johnson   ajayjohnson@gmail.com
# 2  Vijay    Johnson   vijaydanson@gmail.com

# %%
#let's change first and last name
df.loc[2,['first','last']]=['rajesh','danson']

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
#we can use .at to change above
df.at[2,'last']='Johnson'

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh    Johnson   vijaydanson@gmail.com

# %%
# we have to look at this observation
filt=(df['email']=='vijaydanson@gmail.com')

# %%
#df[filt]['last']='danson'- this won't work becuase we are directly applying on temporary  object
df.loc[filt,'last']='danson'

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
df['email']
# Out:
# 0    raotankasala@gmail.com
# 1     ajayjohnson@gmail.com
# 2     vijaydanson@gmail.com
# Name: email, dtype: object

# %%
df['email'].str.lower()
# Out:
# 0    raotankasala@gmail.com
# 1     ajayjohnson@gmail.com
# 2     vijaydanson@gmail.com
# Name: email, dtype: object

# %%
df['email']=df['email'].str.lower()

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
 #apply
 #applymap
 #map
 #replace

# %%
#let's look at apply
df['last'].apply(len)
# Out:
# 0    9
# 1    7
# 2    6
# Name: last, dtype: int64

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    21
# 2    21
# Name: email, dtype: int64

# %%
def update_email(email):
  return email.upper()

# %%
df['email']=df['email'].apply(update_email )

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  RAOTANKASALA@GMAIL.COM
# 1    ajay    Johnson   AJAYJOHNSON@GMAIL.COM
# 2  rajesh     danson   VIJAYDANSON@GMAIL.COM

# %%
df['email']=df['email'].apply(lambda x:x.lower())

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
#let's use apply on dataframe
#it's apply .len on each series of dataframe not on each cell
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(pd.Series.min)
# Out:
# first                      Rao
# last                   Johnson
# email    ajayjohnson@gmail.com
# dtype: object

# %%
#applymap will work for every individual element
df.applymap(len)
# Out:
# /tmp/ipython-input-731525212.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
#    first  last  email
# 0      3     9     22
# 1      4     7     21
# 2      6     6     21

# %%
df.map(len)
# Out:
#    first  last  email
# 0      3     9     22
# 1      4     7     21
# 2      6     6     21

# %%
df.applymap(str.lower)
# Out:
# /tmp/ipython-input-357608748.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(str.lower)
#     first       last                   email
# 0     rao  tankasala  raotankasala@gmail.com
# 1    ajay    johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
df
# Out:
#     first       last                   email
# 0     Rao  Tankasala  raotankasala@gmail.com
# 1    ajay    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
#suppose we want to update couple of firstnames
df['first'].map({'Rao':'Ravi','ajay':'Tarak'})
# Out:
# 0     Ravi
# 1    Tarak
# 2      NaN
# Name: first, dtype: object

# %%
# In above output we can see that we want to change the we just want to change couple of names but unfortunately we can see that other values get changed as NaN
# for that we will use replace
df['first']=df['first'].replace({'Rao':'Ravi','ajay':'Tarak'})

# %%
df
# Out:
#     first       last                   email
# 0    Ravi  Tankasala  raotankasala@gmail.com
# 1   Tarak    Johnson   ajayjohnson@gmail.com
# 2  rajesh     danson   vijaydanson@gmail.com

# %%
import google.colab
google.colab.drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_public.csv')
schema_data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_schema.csv')

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data.shape
# Out:
# (88883, 85)

# %%
schema_data.shape
# Out:
# (85, 2)

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data[['Country','Age','ConvertedComp']].head()
# Out:
#                   Country   Age  ConvertedComp
# 0          United Kingdom  14.0            NaN
# 1  Bosnia and Herzegovina  19.0            NaN
# 2                Thailand  28.0         8820.0
# 3           United States  22.0        61000.0
# 4                 Ukraine  30.0            NaN

# %%
data['Country'].value_counts()['India']
# Out:
# np.int64(9061)

# %%
data['YearsCodePro'].value_counts()['Less than 1 year']
# Out:
# np.int64(3997)

# %%
#Filter rows where Gender equals "Man".
filt= (data['Gender']=='Man')
data[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88875       88182                                                NaN      Yes
# 88876       88212                                                NaN       No
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#Filter respondents whose EdLevel contains "Bachelor" (use .str.contains() inside a filter).

filt= (data['EdLevel'].str.contains('Bachelor',case=False,na=False))
data[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88854       84539                                                NaN      Yes
# 88870       87352                                                NaN      Yes
# 88871       87386                                                NaN      Yes
#
# ...

# %%
#Show 5 rows where LanguageWorkedWith contains "Python".
filt=data['LanguageWorkedWith'].str.contains('Python',case=False,na=False)
data[filt].head()
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
# 3           4          I am a developer by profession       No
# 4           5          I am a developer by profession      Yes
# 7           8             I code primarily as a hobby      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 3                       Never
# 4  Once a month or more often
# 7     Less than once per year
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
# 7  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# ...

# %%
#Show rows where Country is not 'United States'.
filt = (data['Country'] == 'United States')
data[~filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#Use .iloc to show the first 5 rows and first 3 columns.
data.iloc[0:5,0:3]
# Out:
#    Respondent                                         MainBranch Hobbyist
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes

# %%
'''
In EdLevel, use .replace() to change
"Bachelor’s degree (BA, BS, B.Eng., etc.)" → "Bachelor"
"Master’s degree (M.A., M.S., M.Eng., MBA, etc.)" → "Master".
Then print the first 10 rows of that column.
'''

data['EdLevel'].replace({
'Bachelor’s degree (BA, BS, B.Eng., etc.)':'Bachelor',
'Master’s degree (MA, MS, M.Eng., MBA, etc.)':'Master'},inplace=True)
data['EdLevel']
# Out:
# /tmp/ipython-input-373512000.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['EdLevel'].replace({
# 0                                Primary/elementary school
# 1        Secondary school (e.g. American high school, G...
# 2                                                 Bachelor
# 3                                                 Bachelor
# 4                                                 Bachelor
#                                ...
# 88878                            Primary/elementary school
# ...

# %%
#Filter people from India and in EdLevel "Master" → replace "Master" with "Postgraduate".

filt = (data['Country'] == 'India')
data.loc[filt, 'EdLevel'] = data.loc[filt, 'EdLevel'].replace({'Master': 'Postgraduate'})

# %%
data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...
